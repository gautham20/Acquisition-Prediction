# %%
import pandas as pd
import numpy as np

# %%
features = pd.read_pickle('crawl_datas/features_new.pkl')
ys_posts = pd.read_pickle('crawl_datas/ys_posts.pkl')
vc_posts = pd.read_pickle('crawl_datas/vc_posts.pkl')
mn_posts = pd.read_pickle('crawl_datas/mn_posts.pkl')
nbw_posts = pd.read_pickle('crawl_datas/nbw_posts.pkl')

ys_posts['site'] = 'ys'
vc_posts['site'] = 'vc'
mn_posts['site'] = 'mn'
nbw_posts['site'] = 'nbw'

del vc_posts['desc']

posts_dfs = [ys_posts,vc_posts,mn_posts,nbw_posts]
all_posts = pd.concat(posts_dfs)

# %%
all_posts.reset_index(inplace=True)
del all_posts['index']

# %%
all_posts
# Out:
#                                    cname  \
# 0                             [[practo]]
# 1                             [[practo]]
# 2                             [[practo]]
# 3                          [[freshdesk]]
# 4                           [[infibeam]]
# 5                            [[explara]]
# 6                             [[jugnoo]]
# 7               [[freshdesk], [konotor]]
# 8                                [[oyo]]
# 9     [[urban, ladder], [urban, ladder]]
# 10                            [[practo]]
# 11                [[homelane], [doowup]]
# 12                         [[freshdesk]]
# 13    [[urban, ladder], [urban, ladder]]
# 14                   [[realty, compass]]
# 15                            [[practo]]
# 16              [[indusnet, indus, net]]
# 17                            [[redbus]]
# 18                            [[redbus]]
# 19                               [[oyo]]
# 20                            [[redbus]]
# 21                             [[quikr]]
# 22                            [[inmobi]]
# 23                            [[practo]]
# 24                            [[inmobi]]
# 25                         [[shopclues]]
# 26                            [[inmobi]]
# 27                         [[freshdesk]]
# 28                             [[quikr]]
# 29                            [[inmobi]]
# ...                                  ...
# 1852                      [[backpacker]]
# 1853                      [[bankbazaar]]
# 1854                      [[bankbazaar]]
# 1855                      [[bankbazaar]]
# 1856                      [[bankbazaar]]
# 1857                           [[burrp]]
# 1858                  [[burrp], [burrp]]
# 1859                           [[burrp]]
# 1860                           [[burrp]]
# 1861                           [[burrp]]
# 1862                  [[burrp], [burrp]]
# 1863                           [[burrp]]
# 1864                           [[burrp]]
# 1865                           [[burrp]]
# 1866                           [[burrp]]
# 1867                           [[burrp]]
# 1868                           [[burrp]]
# 1869                           [[burrp]]
# 1870                           [[burrp]]
# 1871                           [[burrp]]
# 1872   [[burrp], [indusnet, indus, net]]
# 1873                           [[burrp]]
# 1874                           [[burrp]]
# 1875                           [[burrp]]
# 1876                           [[burrp]]
# 1877                           [[burrp]]
# 1878                        [[adiquity]]
# 1879                        [[adiquity]]
# 1880                        [[adiquity]]
# 1881                        [[adiquity]]
#
#                                                    post site  \
# 0     [after, on, boarding, a, marque, investor, tea...   ys
# 1     [after, its, expansion, into, practo, today, a...   ys
# 2     [it, s, just, a, month, since, and, there, has...   ys
# 3     [cloud, based, customer, support, software, ha...   ys
# 4     [the, first, ever, move, from, an, indian, com...   ys
# 5     [bengaluru, based, diy, event, ticketing, plat...   ys
# 6     [auto, rickshaw, aggregator, jugnoo, which, co...   ys
# 7     [chennai, based, enterprise, software, startup...   ys
# 8     [south, india, s, regional, airline, air, pega...   ys
# 9     [online, furniture, and, home, decor, firm, ur...   ys
# 10    [it, all, began, with, a, funding, announcemen...   ys
# 11    [homelane, com, an, online, home, solutions, p...   ys
# 12    [when, the, freshdesk, founding, team, started...   ys
# 13    [born, and, brought, up, in, bangalore, rajat,...   ys
# 14    [real, estate, portal, housing, com, has, acqu...   ys
# 15    [seven, year, old, healthcare, platform, pract...   ys
# 16    [these, are, the, most, magical, times, for, d...   ys
# 17    [a, couple, of, weeks, ago, ibibogroup, rolled...   ys
# 18    [a, compelling, startup, story, is, that, of, ...   ys
# 19    [japanese, vc, firm, softbank, in, its, annual...   ys
# 20    [whether, it, is, milk, for, your, morning, te...   ys
# 21    [tiger, global, funded, on, demand, home, serv...   ys
# 22    [inmobi, has, found, itself, amidst, a, swirl,...   ys
# 23    [healthcare, booking, platform, practo, and, t...   ys
# 24    [when, we, first, went, to, consumers, telling...   ys
# 25    [founded, in, june, 2015, by, former, ceo, of,...   ys
# 26    [a, made, in, india, journey, of, a, proud, to...   ys
# 27    [founded, by, girish, mathrubootham, in, 2010,...   ys
# 28    [from, mumbai, s, saki, naka, to, bengaluru, s...   ys
# 29    [ola, today, announced, the, release, of, its,...   ys
# ...                                                 ...  ...
# 1852  [roadhouse, undisclosed, ian, not, disclosed, ...  nbw
# 1853  [walden, international, has, invested, 6, mill...  nbw
# 1854  [bankbazaar, a, chennai, based, financial, ser...  nbw
# 1855  [after, amazon, has, announced, an, investment...  nbw
# 1856  [there, are, tons, of, startups, in, financial...  nbw
# 1857  [in, this, with, pluggd, in, deap, talks, abou...  nbw
# 1858  [burrp, has, launched, the, online, tv, progra...  nbw
# 1859  [burrp, after, the, has, launched, burrp, pano...  nbw
# 1860  [burrp, has, launched, events, for, 8, cities,...  nbw
# 1861  [burrp, was, one, of, the, most, loved, web2, ...  nbw
# 1862  [we, have, been, writing, about, burrp, ever, ...  nbw
# 1863  [burrp, boasts, of, 1, 70, 000, listings, 150,...  nbw
# 1864  [there, has, been, back, to, back, good, news,...  nbw
# 1865  [burrp, is, celebrating, its, 5th, anniversary...  nbw
# 1866  [contentsutra, reported, this, and, the, same,...  nbw
# 1867  [i, have, been, following, for, quite, some, t...  nbw
# 1868  [deap, talked, about, around, 8, months, back,...  nbw
# 1869  [has, strong, proof, against, accusing, them, ...  nbw
# 1870  [india, s, premier, online, lifestyle, guide, ...  nbw
# 1871  [sulekha, has, revamped, it, s, service, and, ...  nbw
# 1872  [here, is, the, mid, week, recap, of, events, ...  nbw
# 1873  [web18, and, burrp, s, cozy, relationships, we...  nbw
# 1874  [has, donned, a, new, look, and, has, also, ch...  nbw
# 1875  [i, have, always, loved, for, it, s, organic, ...  nbw
# 1876  [burrp, has, been, an, interesting, community,...  nbw
# 1877  [burrp, has, launched, small, business, enabli...  nbw
# 1878  [owing, to, legal, challenges, and, the, banga...  nbw
# 1879  [guruji, s, adiquity, mobile, ads, platform, h...  nbw
# 1880  [in, a, race, to, become, publi, her, and, mon...  nbw
# 1881  [guruji, s, cash, cow, and, the, company, late...  nbw
#
#                                                   title
# 0     [practo, enters, e, commerce, starts, online, ...
# 1     [practo, acquires, insta, health, to, digitise...
# 2     [practo, on, an, acquisition, spree, gets, doc...
# 3     [freshdesk, on, an, acquisition, spree, bags, ...
# 4     [infibeam, rock, a, bye, baby, the, e, commerc...
# 5     [with, pre, series, a, online, ticketing, plat...
# 6     [jugnoo, partners, with, punjab, national, ban...
# 7     [freshdesk, makes, its, third, acquisition, th...
# 8     [air, pegasus, ties, up, with, oyo, rooms, to,...
# 9     [urban, ladder, to, expand, modular, solution,...
# 10    [after, tencent, yuri, milner, sofina, sequoia...
# 11    [homelane, com, acquires, virtual, tech, start...
# 12    [a, plan, b, that, was, never, needed, freshde...
# 13    [techie, tuesdays, how, this, open, source, en...
# 14    [housing, com, acquires, realty, business, int...
# 15    [practo, is, do, ing, great, secures, 90m, fun...
# 16    [act, like, there, is, no, safety, net, 35, qu...
# 17    [redbus, goes, international, now, in, singapo...
# 18    [the, redbus, mafia, who, are, they, and, what...
# 19    [softbank, confirms, oyo, s, acquisition, of, ...
# 20    [ex, redbus, execs, create, a, whatsapp, like,...
# 21    [quikr, and, flipkart, may, bid, for, horizont...
# 22    [naveen, tewari, spills, the, beans, on, how, ...
# 23    [practo, uber, announce, global, partnership, ...
# 24    [miip, stitches, your, past, experiences, rela...
# 25    [former, ceo, of, airtel, enterprise, starts, ...
# 26    [ambition, innovation, perseverance, inmobi, s...
# 27    [freshdesk, s, hotline, io, provides, in, app,...
# 28    [quikr, s, new, 4, acre, swanky, campus, in, b...
# 29    [ola, opens, up, its, api, aims, to, touch, 10...
# ...                                                 ...
# 1852  [chain, of, backpacker, s, hostel, roadhouse, ...
# 1853  [walden, international, invests, 6, million, i...
# 1854  [bankbazaar, raises, 13, mn, funding, from, se...
# 1855  [amazon, leads, 60mn, investment, in, bankbazaar]
# 1856  [bankbazaar, compare, rates, of, financial, in...
# 1857  [in, deep, conversation, with, deap, ubhi, of,...
# 1858            [exclusive, burrp, launches, burrp, tv]
# 1859  [burrp, launches, virtual, tours, for, busines...
# 1860               [burrp, launches, lifestyle, events]
# 1861  [why, burrp, founder, deap, ubhi, quit, infome...
# 1862  [burrp, launches, burrp, express, an, ultra, c...
# 1863  [news, roundup, burrp, goes, for, a, redesign,...
# 1864  [app, roundup, burrp, and, cleartrip, launch, ...
# 1865  [burrp, story, deep, conversation, with, deap,...
# 1866  [burrp, s, possible, merger, talks, with, mih,...
# 1867                         [let, your, mobile, burrp]
# 1868  [burrp, all, set, to, launch, tv, listing, ser...
# 1869  [zomato, accuses, burrp, of, blatantly, copyin...
# 1870  [burrp, announces, local, event, content, part...
# 1871  [sulekha, revamps, it, s, yellow, page, servic...
# 1872  [mid, week, recap, burrp, adds, pune, govt, pu...
# 1873  [alright, infomedia, 18, acquires, burrp, fina...
# 1874  [burrp, gets, a, new, look, it, s, a, local, s...
# 1875  [burrp, makes, it, big, among, the, top, 30, n...
# 1876  [burrp, gets, into, print, launches, new, year...
# 1877  [burrp, launches, small, business, service, re...
# 1878  [guruji, com, launches, adiquity, mobile, ad, ...
# 1879  [guruji, s, adiquity, launches, real, time, bi...
# 1880  [flipkart, acquires, mobile, ad, platform, adi...
# 1881  [guruji, s, ad, optimization, platform, adiqui...
#
# [1882 rows x 4 columns]

# %%
def get_status(cnames):
    sum = 0
    for cname in cnames:
        cname = ' '.join(cname)
        if cname in ['junotele','netmeds','name','trideal']:
            break
        sum += int( features.ix[cname,'acquired'])
    return float(sum)/len(cnames)


all_posts['acquired'] = all_posts['cname'].apply(get_status)

# %%
all_posts
# Out:
#                                    cname  \
# 0                             [[practo]]
# 1                             [[practo]]
# 2                             [[practo]]
# 3                          [[freshdesk]]
# 4                           [[infibeam]]
# 5                            [[explara]]
# 6                             [[jugnoo]]
# 7               [[freshdesk], [konotor]]
# 8                                [[oyo]]
# 9     [[urban, ladder], [urban, ladder]]
# 10                            [[practo]]
# 11                [[homelane], [doowup]]
# 12                         [[freshdesk]]
# 13    [[urban, ladder], [urban, ladder]]
# 14                   [[realty, compass]]
# 15                            [[practo]]
# 16              [[indusnet, indus, net]]
# 17                            [[redbus]]
# 18                            [[redbus]]
# 19                               [[oyo]]
# 20                            [[redbus]]
# 21                             [[quikr]]
# 22                            [[inmobi]]
# 23                            [[practo]]
# 24                            [[inmobi]]
# 25                         [[shopclues]]
# 26                            [[inmobi]]
# 27                         [[freshdesk]]
# 28                             [[quikr]]
# 29                            [[inmobi]]
# ...                                  ...
# 1852                      [[backpacker]]
# 1853                      [[bankbazaar]]
# 1854                      [[bankbazaar]]
# 1855                      [[bankbazaar]]
# 1856                      [[bankbazaar]]
# 1857                           [[burrp]]
# 1858                  [[burrp], [burrp]]
# 1859                           [[burrp]]
# 1860                           [[burrp]]
# 1861                           [[burrp]]
# 1862                  [[burrp], [burrp]]
# 1863                           [[burrp]]
# 1864                           [[burrp]]
# 1865                           [[burrp]]
# 1866                           [[burrp]]
# 1867                           [[burrp]]
# 1868                           [[burrp]]
# 1869                           [[burrp]]
# 1870                           [[burrp]]
# 1871                           [[burrp]]
# 1872   [[burrp], [indusnet, indus, net]]
# 1873                           [[burrp]]
# 1874                           [[burrp]]
# 1875                           [[burrp]]
# 1876                           [[burrp]]
# 1877                           [[burrp]]
# 1878                        [[adiquity]]
# 1879                        [[adiquity]]
# 1880                        [[adiquity]]
# 1881                        [[adiquity]]
#
#                                                    post site  \
# 0     [after, on, boarding, a, marque, investor, tea...   ys
# 1     [after, its, expansion, into, practo, today, a...   ys
# 2     [it, s, just, a, month, since, and, there, has...   ys
# 3     [cloud, based, customer, support, software, ha...   ys
# 4     [the, first, ever, move, from, an, indian, com...   ys
# 5     [bengaluru, based, diy, event, ticketing, plat...   ys
# 6     [auto, rickshaw, aggregator, jugnoo, which, co...   ys
# 7     [chennai, based, enterprise, software, startup...   ys
# 8     [south, india, s, regional, airline, air, pega...   ys
# 9     [online, furniture, and, home, decor, firm, ur...   ys
# 10    [it, all, began, with, a, funding, announcemen...   ys
# 11    [homelane, com, an, online, home, solutions, p...   ys
# 12    [when, the, freshdesk, founding, team, started...   ys
# 13    [born, and, brought, up, in, bangalore, rajat,...   ys
# 14    [real, estate, portal, housing, com, has, acqu...   ys
# 15    [seven, year, old, healthcare, platform, pract...   ys
# 16    [these, are, the, most, magical, times, for, d...   ys
# 17    [a, couple, of, weeks, ago, ibibogroup, rolled...   ys
# 18    [a, compelling, startup, story, is, that, of, ...   ys
# 19    [japanese, vc, firm, softbank, in, its, annual...   ys
# 20    [whether, it, is, milk, for, your, morning, te...   ys
# 21    [tiger, global, funded, on, demand, home, serv...   ys
# 22    [inmobi, has, found, itself, amidst, a, swirl,...   ys
# 23    [healthcare, booking, platform, practo, and, t...   ys
# 24    [when, we, first, went, to, consumers, telling...   ys
# 25    [founded, in, june, 2015, by, former, ceo, of,...   ys
# 26    [a, made, in, india, journey, of, a, proud, to...   ys
# 27    [founded, by, girish, mathrubootham, in, 2010,...   ys
# 28    [from, mumbai, s, saki, naka, to, bengaluru, s...   ys
# 29    [ola, today, announced, the, release, of, its,...   ys
# ...                                                 ...  ...
# 1852  [roadhouse, undisclosed, ian, not, disclosed, ...  nbw
# 1853  [walden, international, has, invested, 6, mill...  nbw
# 1854  [bankbazaar, a, chennai, based, financial, ser...  nbw
# 1855  [after, amazon, has, announced, an, investment...  nbw
# 1856  [there, are, tons, of, startups, in, financial...  nbw
# 1857  [in, this, with, pluggd, in, deap, talks, abou...  nbw
# 1858  [burrp, has, launched, the, online, tv, progra...  nbw
# 1859  [burrp, after, the, has, launched, burrp, pano...  nbw
# 1860  [burrp, has, launched, events, for, 8, cities,...  nbw
# 1861  [burrp, was, one, of, the, most, loved, web2, ...  nbw
# 1862  [we, have, been, writing, about, burrp, ever, ...  nbw
# 1863  [burrp, boasts, of, 1, 70, 000, listings, 150,...  nbw
# 1864  [there, has, been, back, to, back, good, news,...  nbw
# 1865  [burrp, is, celebrating, its, 5th, anniversary...  nbw
# 1866  [contentsutra, reported, this, and, the, same,...  nbw
# 1867  [i, have, been, following, for, quite, some, t...  nbw
# 1868  [deap, talked, about, around, 8, months, back,...  nbw
# 1869  [has, strong, proof, against, accusing, them, ...  nbw
# 1870  [india, s, premier, online, lifestyle, guide, ...  nbw
# 1871  [sulekha, has, revamped, it, s, service, and, ...  nbw
# 1872  [here, is, the, mid, week, recap, of, events, ...  nbw
# 1873  [web18, and, burrp, s, cozy, relationships, we...  nbw
# 1874  [has, donned, a, new, look, and, has, also, ch...  nbw
# 1875  [i, have, always, loved, for, it, s, organic, ...  nbw
# 1876  [burrp, has, been, an, interesting, community,...  nbw
# 1877  [burrp, has, launched, small, business, enabli...  nbw
# 1878  [owing, to, legal, challenges, and, the, banga...  nbw
# 1879  [guruji, s, adiquity, mobile, ads, platform, h...  nbw
# 1880  [in, a, race, to, become, publi, her, and, mon...  nbw
# 1881  [guruji, s, cash, cow, and, the, company, late...  nbw
#
#                                                   title  acquired
# 0     [practo, enters, e, commerce, starts, online, ...       0.0
# 1     [practo, acquires, insta, health, to, digitise...       0.0
# 2     [practo, on, an, acquisition, spree, gets, doc...       0.0
# 3     [freshdesk, on, an, acquisition, spree, bags, ...       0.0
# 4     [infibeam, rock, a, bye, baby, the, e, commerc...       0.0
# 5     [with, pre, series, a, online, ticketing, plat...       0.0
# 6     [jugnoo, partners, with, punjab, national, ban...       0.0
# 7     [freshdesk, makes, its, third, acquisition, th...       0.5
# 8     [air, pegasus, ties, up, with, oyo, rooms, to,...       0.0
# 9     [urban, ladder, to, expand, modular, solution,...       0.0
# 10    [after, tencent, yuri, milner, sofina, sequoia...       0.0
# 11    [homelane, com, acquires, virtual, tech, start...       0.5
# 12    [a, plan, b, that, was, never, needed, freshde...       0.0
# 13    [techie, tuesdays, how, this, open, source, en...       0.0
# 14    [housing, com, acquires, realty, business, int...       1.0
# 15    [practo, is, do, ing, great, secures, 90m, fun...       0.0
# 16    [act, like, there, is, no, safety, net, 35, qu...       0.0
# 17    [redbus, goes, international, now, in, singapo...       1.0
# 18    [the, redbus, mafia, who, are, they, and, what...       1.0
# 19    [softbank, confirms, oyo, s, acquisition, of, ...       0.0
# 20    [ex, redbus, execs, create, a, whatsapp, like,...       1.0
# 21    [quikr, and, flipkart, may, bid, for, horizont...       0.0
# 22    [naveen, tewari, spills, the, beans, on, how, ...       0.0
# 23    [practo, uber, announce, global, partnership, ...       0.0
# 24    [miip, stitches, your, past, experiences, rela...       0.0
# 25    [former, ceo, of, airtel, enterprise, starts, ...       0.0
# 26    [ambition, innovation, perseverance, inmobi, s...       0.0
# 27    [freshdesk, s, hotline, io, provides, in, app,...       0.0
# 28    [quikr, s, new, 4, acre, swanky, campus, in, b...       0.0
# 29    [ola, opens, up, its, api, aims, to, touch, 10...       0.0
# ...                                                 ...       ...
# 1852  [chain, of, backpacker, s, hostel, roadhouse, ...       0.0
# 1853  [walden, international, invests, 6, million, i...       0.0
# 1854  [bankbazaar, raises, 13, mn, funding, from, se...       0.0
# 1855  [amazon, leads, 60mn, investment, in, bankbazaar]       0.0
# 1856  [bankbazaar, compare, rates, of, financial, in...       0.0
# 1857  [in, deep, conversation, with, deap, ubhi, of,...       0.0
# 1858            [exclusive, burrp, launches, burrp, tv]       0.0
# 1859  [burrp, launches, virtual, tours, for, busines...       0.0
# 1860               [burrp, launches, lifestyle, events]       0.0
# 1861  [why, burrp, founder, deap, ubhi, quit, infome...       0.0
# 1862  [burrp, launches, burrp, express, an, ultra, c...       0.0
# 1863  [news, roundup, burrp, goes, for, a, redesign,...       0.0
# 1864  [app, roundup, burrp, and, cleartrip, launch, ...       0.0
# 1865  [burrp, story, deep, conversation, with, deap,...       0.0
# 1866  [burrp, s, possible, merger, talks, with, mih,...       0.0
# 1867                         [let, your, mobile, burrp]       0.0
# 1868  [burrp, all, set, to, launch, tv, listing, ser...       0.0
# 1869  [zomato, accuses, burrp, of, blatantly, copyin...       0.0
# 1870  [burrp, announces, local, event, content, part...       0.0
# 1871  [sulekha, revamps, it, s, yellow, page, servic...       0.0
# 1872  [mid, week, recap, burrp, adds, pune, govt, pu...       0.0
# 1873  [alright, infomedia, 18, acquires, burrp, fina...       0.0
# 1874  [burrp, gets, a, new, look, it, s, a, local, s...       0.0
# 1875  [burrp, makes, it, big, among, the, top, 30, n...       0.0
# 1876  [burrp, gets, into, print, launches, new, year...       0.0
# 1877  [burrp, launches, small, business, service, re...       0.0
# 1878  [guruji, com, launches, adiquity, mobile, ad, ...       0.0
# 1879  [guruji, s, adiquity, launches, real, time, bi...       0.0
# 1880  [flipkart, acquires, mobile, ad, platform, adi...       0.0
# 1881  [guruji, s, ad, optimization, platform, adiqui...       0.0
#
# [1882 rows x 5 columns]

# %% [markdown]
# <h1> Doc Vectors </h1>

# %%
from gensim import utils
from gensim.models import Doc2Vec
from gensim.models.doc2vec import LabeledSentence

from random import shuffle

from sklearn.linear_model import LogisticRegression
# Out:
# Using gpu device 0: GeForce GT 740M
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/gautham/AppData/Local/Theano/compiledir_Windows-10-10.0.10586-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.11-64/tmp3j6cft/c8d7bd33dfef61705c2854dd1f0cb7ce.lib and object C:/Users/gautham/AppData/Local/Theano/compiledir_Windows-10-10.0.10586-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.11-64/tmp3j6cft/c8d7bd33dfef61705c2854dd1f0cb7ce.exp
#
# DEBUG: nvcc STDOUT mod.cu
#    Creating library C:/Users/gautham/AppData/Local/Theano/compiledir_Windows-10-10.0.10586-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.11-64/tmpj6ixun/0fc80e98cce631ecaa526b69dd28dae1.lib and object C:/Users/gautham/AppData/Local/Theano/compiledir_Windows-10-10.0.10586-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.11-64/tmpj6ixun/0fc80e98cce631ecaa526b69dd28dae1.exp

# %%
all_posts.reset_index(inplace=True)

# %%
labeled_posts = []
def get_labelpost(row):
    labeled_posts.append(LabeledSentence(row['post'],[row['site']+'_'+str(row['index'])]))
    labeled_posts.append(LabeledSentence(row['title'],[row['site']+'_t_'+str(row['index'])]))
#all_posts.reset_index(inplace=True)
all_posts.apply(get_labelpost,axis=1)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# 5       None
# 6       None
# 7       None
# 8       None
# 9       None
# 10      None
# 11      None
# 12      None
# 13      None
# 14      None
# 15      None
# 16      None
# 17      None
# 18      None
# 19      None
# 20      None
# 21      None
# 22      None
# 23      None
# 24      None
# 25      None
# 26      None
# 27      None
# 28      None
# 29      None
#         ...
# 1852    None
# 1853    None
# 1854    None
# 1855    None
# 1856    None
# 1857    None
# 1858    None
# 1859    None
# 1860    None
# 1861    None
# 1862    None
# 1863    None
# 1864    None
# 1865    None
# 1866    None
# 1867    None
# 1868    None
# 1869    None
# 1870    None
# 1871    None
# 1872    None
# 1873    None
# 1874    None
# 1875    None
# 1876    None
# 1877    None
# 1878    None
# 1879    None
# 1880    None
# 1881    None
# dtype: object

# %%
len(labeled_posts)
# Out:
# 3764

# %%
import multiprocessing

cores = multiprocessing.cpu_count()

model  = Doc2Vec(dm=1, hs=1, min_count=1,
                 window=5, size=200, negative=5, 
                 sample=1e-5, workers= cores)
model.build_vocab(labeled_posts)

# %%
from contextlib import contextmanager
from timeit import default_timer
import time
import datetime
@contextmanager
def elapsed_timer():
    start = default_timer()
    elapser = lambda: default_timer() - start
    yield lambda: elapser()
    end = default_timer()
    elapser = lambda: end-start

print(datetime.datetime.now())
for epoch in range(10):
    with elapsed_timer() as elapser:
        shuffle(labeled_posts)
        model.train(labeled_posts)
    print 'epoch {0} completed in {1}'.format(epoch+1,elapser())
# Out:
# 2016-08-31 00:14:38.165000
# epoch 1 completed in 4.96469018569
# epoch 2 completed in 4.37376725501
# epoch 3 completed in 4.50146299505
# epoch 4 completed in 4.39449354762
# epoch 5 completed in 4.44373492592
# epoch 6 completed in 4.40570291939
# epoch 7 completed in 4.39654276701
# epoch 8 completed in 4.40061139362
# epoch 9 completed in 4.38732592265
# epoch 10 completed in 4.39057495925

# %%
model.save('all_posts.d2v')

# %%
model = Doc2Vec.load('all_posts.d2v')

# %%
model.most_similar('housing')
# Out:
# [('realty', 0.5279401540756226),
#  ('estate', 0.5134611129760742),
#  ('99acres', 0.4494507908821106),
#  ('homebuy360', 0.4270632863044739),
#  ('talks', 0.425751268863678),
#  ('acquires', 0.41518956422805786),
#  ('zigwheels', 0.41190406680107117),
#  ('commonfloor', 0.41157472133636475),
#  ('realtybi', 0.40710341930389404),
#  ('irx', 0.40466415882110596)]

# %%
model.most_similar('tastykhana')
# Out:
# [('foodpanda', 0.5239710807800293),
#  ('hero', 0.5177308320999146),
#  ('deliveryhero', 0.4281463623046875),
#  ('ordering', 0.41517361998558044),
#  ('mexican', 0.37491199374198914),
#  ('invests', 0.3735084533691406),
#  ('openings', 0.3630988597869873),
#  ('delhiveryhero', 0.36052581667900085),
#  ('sponsors', 0.35396450757980347),
#  ('simplilearn', 0.34919360280036926)]

# %%
model.most_similar('freshdesk')
# Out:
# [('mathrubootham', 0.5840067267417908),
#  ('girish', 0.5170499086380005),
#  ('support', 0.5058464407920837),
#  ('accel', 0.43377551436424255),
#  ('desk', 0.42272576689720154),
#  ('helpdesk', 0.41424673795700073),
#  ('shanmugam', 0.40274983644485474),
#  ('31m', 0.3967704176902771),
#  ('1click', 0.39513111114501953),
#  ('tiger', 0.39016714692115784)]

# %%
model.most_similar('konotor')
# Out:
# [('1click', 0.4552173614501953),
#  ('developers', 0.45263853669166565),
#  ('frilp', 0.4510992765426636),
#  ('provides', 0.4319232106208801),
#  ('desk', 0.4311426281929016),
#  ('freshmobile', 0.43082135915756226),
#  ('framebench', 0.4261656701564789),
#  ('cloud', 0.41782355308532715),
#  ('io', 0.40844497084617615),
#  ('support', 0.40563637018203735)]

# %%
model.most_similar('frilp')
# Out:
# [('1click', 0.556711733341217),
#  ('framebench', 0.4724140167236328),
#  ('konotor', 0.451099157333374),
#  ('trulymadly', 0.42210566997528076),
#  ('promos', 0.4186643064022064),
#  ('crowdsource', 0.41736873984336853),
#  ('chat', 0.4160081148147583),
#  ('kahuna', 0.41413378715515137),
#  ('12m', 0.4098050892353058),
#  ('todo', 0.39092308282852173)]

# %%
labels = []
cname = []

def map_cname_label(row):
    labels.append(row['site']+'_'+str(row['index']))
    cname.append(row['cname'])
    labels.append(row['site']+'_t_'+str(row['index']))
    cname.append(row['cname'])
    
    
all_posts.apply(map_cname_label,axis=1)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# 5       None
# 6       None
# 7       None
# 8       None
# 9       None
# 10      None
# 11      None
# 12      None
# 13      None
# 14      None
# 15      None
# 16      None
# 17      None
# 18      None
# 19      None
# 20      None
# 21      None
# 22      None
# 23      None
# 24      None
# 25      None
# 26      None
# 27      None
# 28      None
# 29      None
#         ...
# 1852    None
# 1853    None
# 1854    None
# 1855    None
# 1856    None
# 1857    None
# 1858    None
# 1859    None
# 1860    None
# 1861    None
# 1862    None
# 1863    None
# 1864    None
# 1865    None
# 1866    None
# 1867    None
# 1868    None
# 1869    None
# 1870    None
# 1871    None
# 1872    None
# 1873    None
# 1874    None
# 1875    None
# 1876    None
# 1877    None
# 1878    None
# 1879    None
# 1880    None
# 1881    None
# dtype: object

# %%
cname_map = pd.DataFrame({'labels':labels,'cnames':cname})

# %%
cname_map
# Out:
#                                   cnames      labels
# 0                             [[practo]]        ys_0
# 1                             [[practo]]      ys_t_0
# 2                             [[practo]]        ys_1
# 3                             [[practo]]      ys_t_1
# 4                             [[practo]]        ys_2
# 5                             [[practo]]      ys_t_2
# 6                          [[freshdesk]]        ys_3
# 7                          [[freshdesk]]      ys_t_3
# 8                           [[infibeam]]        ys_4
# 9                           [[infibeam]]      ys_t_4
# 10                           [[explara]]        ys_5
# 11                           [[explara]]      ys_t_5
# 12                            [[jugnoo]]        ys_6
# 13                            [[jugnoo]]      ys_t_6
# 14              [[freshdesk], [konotor]]        ys_7
# 15              [[freshdesk], [konotor]]      ys_t_7
# 16                               [[oyo]]        ys_8
# 17                               [[oyo]]      ys_t_8
# 18    [[urban, ladder], [urban, ladder]]        ys_9
# 19    [[urban, ladder], [urban, ladder]]      ys_t_9
# 20                            [[practo]]       ys_10
# 21                            [[practo]]     ys_t_10
# 22                [[homelane], [doowup]]       ys_11
# 23                [[homelane], [doowup]]     ys_t_11
# 24                         [[freshdesk]]       ys_12
# 25                         [[freshdesk]]     ys_t_12
# 26    [[urban, ladder], [urban, ladder]]       ys_13
# 27    [[urban, ladder], [urban, ladder]]     ys_t_13
# 28                   [[realty, compass]]       ys_14
# 29                   [[realty, compass]]     ys_t_14
# ...                                  ...         ...
# 3734                           [[burrp]]    nbw_1867
# 3735                           [[burrp]]  nbw_t_1867
# 3736                           [[burrp]]    nbw_1868
# 3737                           [[burrp]]  nbw_t_1868
# 3738                           [[burrp]]    nbw_1869
# 3739                           [[burrp]]  nbw_t_1869
# 3740                           [[burrp]]    nbw_1870
# 3741                           [[burrp]]  nbw_t_1870
# 3742                           [[burrp]]    nbw_1871
# 3743                           [[burrp]]  nbw_t_1871
# 3744   [[burrp], [indusnet, indus, net]]    nbw_1872
# 3745   [[burrp], [indusnet, indus, net]]  nbw_t_1872
# 3746                           [[burrp]]    nbw_1873
# 3747                           [[burrp]]  nbw_t_1873
# 3748                           [[burrp]]    nbw_1874
# 3749                           [[burrp]]  nbw_t_1874
# 3750                           [[burrp]]    nbw_1875
# 3751                           [[burrp]]  nbw_t_1875
# 3752                           [[burrp]]    nbw_1876
# 3753                           [[burrp]]  nbw_t_1876
# 3754                           [[burrp]]    nbw_1877
# 3755                           [[burrp]]  nbw_t_1877
# 3756                        [[adiquity]]    nbw_1878
# 3757                        [[adiquity]]  nbw_t_1878
# 3758                        [[adiquity]]    nbw_1879
# 3759                        [[adiquity]]  nbw_t_1879
# 3760                        [[adiquity]]    nbw_1880
# 3761                        [[adiquity]]  nbw_t_1880
# 3762                        [[adiquity]]    nbw_1881
# 3763                        [[adiquity]]  nbw_t_1881
#
# [3764 rows x 2 columns]

# %%
cname_vec = {}

# %%
def get_vecagg(row):
    global cname_vec
    vec = model.docvecs[row['labels']]
    for c in row['cnames']:
        c = ' '.join(c)
        if c in cname_vec.keys():
            prev_vec = cname_vec[c]
            cname_vec[c] = vec+prev_vec
        else:
            cname_vec[c] = vec

cname_map.apply(get_vecagg,axis=1)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# 5       None
# 6       None
# 7       None
# 8       None
# 9       None
# 10      None
# 11      None
# 12      None
# 13      None
# 14      None
# 15      None
# 16      None
# 17      None
# 18      None
# 19      None
# 20      None
# 21      None
# 22      None
# 23      None
# 24      None
# 25      None
# 26      None
# 27      None
# 28      None
# 29      None
#         ...
# 3734    None
# 3735    None
# 3736    None
# 3737    None
# 3738    None
# 3739    None
# 3740    None
# 3741    None
# 3742    None
# 3743    None
# 3744    None
# 3745    None
# 3746    None
# 3747    None
# 3748    None
# 3749    None
# 3750    None
# 3751    None
# 3752    None
# 3753    None
# 3754    None
# 3755    None
# 3756    None
# 3757    None
# 3758    None
# 3759    None
# 3760    None
# 3761    None
# 3762    None
# 3763    None
# dtype: object

# %%
cname_vec.keys()
# Out:
# ['appknox',
#  'fractal analytics',
#  'exotel',
#  'martjack',
#  'pickingo',
#  'witworks',
#  'komli',
#  'tastykhana',
#  'backpacker',
#  'opinio',
#  'homelane',
#  'admagnet',
#  'adiquity',
#  'rivigo',
#  'antuit',
#  'toppr',
#  'quikr',
#  'name',
#  'cardekho',
#  'mygola',
#  'freecharge',
#  'junotele',
#  'parcelled',
#  'limeroad',
#  'unmetric',
#  'manthan',
#  'infibeam',
#  'vauntz',
#  'doowup',
#  'linkstreet',
#  'madrat',
#  'martmobi',
#  'explara',
#  'thrill',
#  'nowfloats',
#  'instamojo',
#  'wittyfeed',
#  'urbanspoon',
#  'bankbazaar',
#  'webengage',
#  'lybrate',
#  'inmobi',
#  'mobstac',
#  'hackerrank',
#  'appiterate',
#  'deskaway',
#  'juspay',
#  'tinyowl',
#  'shifu',
#  'jabong',
#  'redbus',
#  'homebuy360',
#  'croak',
#  'zipdial',
#  'freshdesk',
#  'meru',
#  'firstcry',
#  'tommyjams',
#  'townrush',
#  'magicbricks',
#  'jombay',
#  'shopify',
#  'supportbee',
#  'housing',
#  'saavn',
#  'frilp',
#  'jugnoo',
#  'taxiforsure',
#  'konotor',
#  'realty compass',
#  'indusnet indus net',
#  'delhivery',
#  'native5',
#  'mobikwik',
#  'eventifier',
#  'zepper',
#  'makaan',
#  'fitho',
#  'practo',
#  'unicommerce',
#  'insta health',
#  'trideal',
#  'urban ladder',
#  'oyo',
#  'babyoye',
#  'gapoon',
#  'burrp',
#  'shopclues',
#  'pepperfry',
#  'tookitaki',
#  'vserv',
#  'carwale',
#  'netmeds',
#  'qikpod',
#  'pubmatic',
#  'heckyl']

# %%
post_cname = cname_vec.keys()
post_cname
# Out:
# ['appknox',
#  'fractal analytics',
#  'exotel',
#  'martjack',
#  'pickingo',
#  'witworks',
#  'komli',
#  'tastykhana',
#  'backpacker',
#  'opinio',
#  'homelane',
#  'admagnet',
#  'adiquity',
#  'rivigo',
#  'antuit',
#  'toppr',
#  'quikr',
#  'name',
#  'cardekho',
#  'mygola',
#  'freecharge',
#  'junotele',
#  'parcelled',
#  'limeroad',
#  'unmetric',
#  'manthan',
#  'infibeam',
#  'vauntz',
#  'doowup',
#  'linkstreet',
#  'madrat',
#  'martmobi',
#  'explara',
#  'thrill',
#  'nowfloats',
#  'instamojo',
#  'wittyfeed',
#  'urbanspoon',
#  'bankbazaar',
#  'webengage',
#  'lybrate',
#  'inmobi',
#  'mobstac',
#  'hackerrank',
#  'appiterate',
#  'deskaway',
#  'juspay',
#  'tinyowl',
#  'shifu',
#  'jabong',
#  'redbus',
#  'homebuy360',
#  'croak',
#  'zipdial',
#  'freshdesk',
#  'meru',
#  'firstcry',
#  'tommyjams',
#  'townrush',
#  'magicbricks',
#  'jombay',
#  'shopify',
#  'supportbee',
#  'housing',
#  'saavn',
#  'frilp',
#  'jugnoo',
#  'taxiforsure',
#  'konotor',
#  'realty compass',
#  'indusnet indus net',
#  'delhivery',
#  'native5',
#  'mobikwik',
#  'eventifier',
#  'zepper',
#  'makaan',
#  'fitho',
#  'practo',
#  'unicommerce',
#  'insta health',
#  'trideal',
#  'urban ladder',
#  'oyo',
#  'babyoye',
#  'gapoon',
#  'burrp',
#  'shopclues',
#  'pepperfry',
#  'tookitaki',
#  'vserv',
#  'carwale',
#  'netmeds',
#  'qikpod',
#  'pubmatic',
#  'heckyl']

# %%
all_cname = list(features['name'])
all_cname
# Out:
# ['appknox',
#  'backpacker',
#  'cloudboost',
#  'explara',
#  'fugenx',
#  'hackerrank',
#  'heckyl',
#  'indusnet indus net',
#  'infibeam',
#  'jugnoo',
#  'juspay',
#  'kayako',
#  'letsventure',
#  'limeroad',
#  'linkstreet',
#  'lybrate',
#  'machinepulse',
#  'madrat',
#  'makaan',
#  'mygola',
#  'nowfloats',
#  'pickingo',
#  'realty compass',
#  'threadsol',
#  'thrill',
#  'tommyjams',
#  'tookitaki',
#  'toppr',
#  'unicommerce',
#  'unmetric',
#  'vauntz',
#  'webengage',
#  'zepper',
#  'admagnet',
#  'antuit',
#  'bankbazaar',
#  'bigbasket.com',
#  'croak.it',
#  'delhivery',
#  'deskaway',
#  'doowup',
#  'exotel',
#  'fitho',
#  'freshdesk',
#  'grofer',
#  'homelane',
#  'housing.com',
#  'instamojo',
#  'jombay',
#  'jumkey',
#  'konotor',
#  'liquavista',
#  'manthan',
#  'mobstac',
#  'native5',
#  'oyo',
#  'pepperfry',
#  'pinclick',
#  'practo',
#  'pratilipi',
#  'pubmatic',
#  'quikr',
#  'redbus',
#  'saavn',
#  'shopclues',
#  'supportbee',
#  'townrush',
#  'urban ladder',
#  'vserv',
#  'wittyfeed',
#  'witworks',
#  'adiquity',
#  'appiterate',
#  'babyoye',
#  'burrp',
#  'cardekho',
#  'carwale',
#  'eventifier',
#  'firstcry',
#  'fractal analytics',
#  'freecharge',
#  'frilp',
#  'gapoon',
#  'homebuy360',
#  'insta health',
#  'jabong',
#  'komli',
#  'magicbricks',
#  'martjack',
#  'martmobi',
#  'medidart',
#  'meru',
#  'mobikwik',
#  'opinio',
#  'parcelled',
#  'qikpod',
#  'rivigo',
#  'shifu',
#  'shopify',
#  'tastykhana',
#  'taxiforsure',
#  'tinyowl',
#  'urbanspoon',
#  'zipdial',
#  'housing',
#  'croak',
#  'inmobi']

# %%
set(all_cname).difference(set(post_cname))
# Out:
# {'bigbasket.com',
#  'cloudboost',
#  'croak.it',
#  'fugenx',
#  'grofer',
#  'housing.com',
#  'jumkey',
#  'kayako',
#  'letsventure',
#  'liquavista',
#  'machinepulse',
#  'medidart',
#  'pinclick',
#  'pratilipi',
#  'threadsol'}

# %%
vec_df = pd.DataFrame(cname_vec).T

# %%
vec_df
# Out:
#                          0          1          2          3          4    \
# adiquity            6.095442  -0.384010   2.118524  -4.573643   6.839830
# admagnet           -3.933289   2.611545  -0.514441  -0.904114   6.215644
# antuit              1.625175   0.429878   0.096096   0.301241   1.915191
# appiterate          3.907047  -1.534492   2.700393 -11.384540   5.987876
# appknox            -1.046464   1.908051  -2.508015  -2.203620  -0.506814
# babyoye           -16.338200   6.921768  -4.747227  -4.347653   6.425167
# backpacker         -0.601401   6.087700  -1.149415 -11.120674   2.032969
# bankbazaar         -0.163614   7.085605  -2.502302  -8.732586   2.096336
# burrp               5.495484   1.698862 -23.806908 -27.452366   9.497677
# cardekho          -17.984728   1.071310  -2.409578  -7.787544  18.128227
# carwale            -3.964241   2.543842  -6.703001  -1.019585   4.835114
# croak               0.461661   3.649892   0.454177   0.294882   0.627966
# delhivery          -6.484064   5.638927  -5.288878 -11.799816  10.015519
# deskaway            1.869457   1.021696  -5.792532  -4.629005   4.329287
# doowup             -0.699117   0.392555   1.067545  -0.378546   1.477073
# eventifier         -1.154010   7.880155  -4.850804 -11.415249   6.274510
# exotel             -3.930588  18.395533  -2.082319  -4.737268   6.466765
# explara             7.970877   0.684339 -10.764871 -15.320891   3.849942
# firstcry          -11.850974  10.299588   2.089837 -13.286595   9.085392
# fitho              -2.474134   5.495753  -0.387060  -1.239158   5.629352
# fractal analytics  -2.823113  33.199799   1.549003 -33.649227  25.330534
# freecharge          3.597401  52.130402 -24.100756 -41.352161  42.871689
# freshdesk         -16.430304  35.118782  -3.549697 -41.873310  53.246151
# frilp              -1.151562   2.710439   3.608341   1.043951   5.080792
# gapoon             -1.583410   2.180373  -0.175175   0.030742   2.327065
# hackerrank          2.552086   1.260625  -1.465116  -4.447367   3.449926
# heckyl             -7.236139  14.407660   2.982007 -11.158109   3.694097
# homebuy360         -0.612800   8.185953   1.049665  -1.998655  -0.618752
# homelane            0.302608  -2.705254   4.601655  -5.317853   1.276947
# housing             0.048612  12.510216   1.342005 -12.626247   2.908512
# ...                      ...        ...        ...        ...        ...
# qikpod             -3.119015  -0.827467  -2.724632  -1.718791   0.238966
# quikr             -10.826462  26.537275 -24.552294 -22.302517  38.226585
# realty compass     -3.842483   8.949987 -10.330401  -2.973278   9.349569
# redbus             -3.569272  73.627350 -36.561203 -70.143646  54.341896
# rivigo             -2.183823   1.584446  -0.846849  -2.051002   2.116416
# saavn              -5.235900 -23.060148  -2.728161 -30.869228  16.434454
# shifu              -1.383369   5.865006  -4.691152  -3.947389   5.555596
# shopclues         -15.647841   4.490108   0.317728 -41.388882  28.799631
# shopify             3.013701   2.599466  -6.759743 -13.190031  11.517054
# supportbee         -0.596484   0.782888  -1.910029  -4.652853   1.586191
# tastykhana          2.077874   9.433743  -6.038105 -10.199275   5.004033
# taxiforsure         1.912135  88.859268 -69.104889 -67.006538  54.766811
# thrill             -1.132009   3.253110  -0.214570   0.335911  -0.131822
# tinyowl            -4.431743  18.449514   2.727070 -35.193485   0.886056
# tommyjams           0.816089  -0.009694  -1.934659  -1.961817   1.317881
# tookitaki           1.948866  -0.753259   2.820761  -1.959452   3.516385
# toppr              -8.631380   7.275991   7.785040  -2.642117  -1.866633
# townrush           -1.775603   1.123587   1.141165  -3.260168   1.422360
# trideal            -1.388387   0.947506   1.388713  -3.317223  -0.314064
# unicommerce        -1.099576  -6.519916   3.321749   0.061808   2.748689
# unmetric            0.507467   2.756223   2.344909  -1.102807   4.470787
# urban ladder      -23.278412  20.084827 -10.321380 -36.128044  10.000354
# urbanspoon          2.043467   5.685841  -1.254167 -12.335932  -1.799038
# vauntz             -2.754849  -3.960474  -0.627108   2.907135   0.809016
# vserv              11.020424   3.129168  -7.730803 -32.508427  42.503853
# webengage           5.019986   6.040377  -7.242947   1.924371   4.815917
# wittyfeed          -1.323375  -0.151450   2.016054  -0.106077   0.207411
# witworks            0.451338   0.916783  -0.991040   0.372516  -2.342694
# zepper              1.886805   3.146605  -2.079390  -1.926615   3.006999
# zipdial             7.634697   9.708799 -25.914646 -10.369451   3.266211
#
#                          5          6          7          8          9    \
# adiquity           -2.016322   5.056114   6.154154  -9.471286  -5.369165
# admagnet           -3.834968  -1.220984   2.364998  -2.254915  -3.083751
# antuit             -1.149361  -2.790197  -0.759947   0.066572  -0.178925
# appiterate         -0.926288   0.490440  16.426630  -6.743738  -5.010009
# appknox            -1.354483   3.341947   1.689208  -5.112165  -1.051153
# babyoye             6.225708 -18.164024   4.765369  -9.211883 -14.280066
# backpacker          5.833905 -14.090513  -0.619183 -12.477149 -17.415644
# bankbazaar          5.765410   0.949310   4.786913   8.461727 -12.956447
# burrp             -28.374470 -23.287617   1.640384 -37.933071 -59.795544
# cardekho            0.540441 -29.916143  19.256432 -17.724581 -15.920527
# carwale            -2.427643  -5.910921   0.476948 -11.051591  -4.392192
# croak              -2.053219   0.955017   0.860097  -1.689868  -0.988847
# delhivery           7.080872 -11.173186  12.037066 -13.216895  -6.480239
# deskaway           -0.328624   2.514902   0.117025  -8.124866  -3.503215
# doowup             -1.625135  -1.823454   3.443221  -1.976434   1.649505
# eventifier          1.623399  -1.291752   2.200829  -3.231271  -3.913147
# exotel            -12.079530   3.232724   5.411754  -8.907711 -12.104525
# explara             2.058669  -3.693429  -9.275299 -11.948338  -4.119132
# firstcry            3.570561 -22.375460  11.798750  -8.689727 -20.263874
# fitho              -2.974453   1.361069  -0.827508  -1.646685  -8.541999
# fractal analytics  -3.414039 -25.974060  19.698103 -46.427261 -41.618721
# freecharge          7.878109 -32.213673  28.787125 -81.789398 -21.570417
# freshdesk         -16.363462 -30.356689  15.972484 -65.486046 -43.481369
# frilp              -1.864509  -2.933479  -0.165587  -1.223536   0.057224
# gapoon             -0.200555  -1.562945   0.236554  -2.256202  -0.344706
# hackerrank          0.713075  -2.889284  -1.846456  -7.076140  -7.575149
# heckyl            -11.267441  -6.596227  -0.866313  -9.224508 -10.077786
# homebuy360          1.790219  -1.374810   5.188695  -8.804626  -6.829552
# homelane           -2.080304  -5.690188   8.283792 -10.823944  -4.121277
# housing             8.998549  -9.987882   7.645345 -17.244411  -7.000627
# ...                      ...        ...        ...        ...        ...
# qikpod              1.712041  -0.399791   1.383713  -3.185616   1.300671
# quikr              14.979356 -57.950653  39.693878 -62.687248 -53.617271
# realty compass      2.882993  -5.274334   6.763806 -17.778679 -15.608597
# redbus             16.303637  -9.650764  43.656532 -70.396378 -67.011093
# rivigo              2.831296  -4.117532  -0.405983  -2.802412  -0.873654
# saavn             -16.572685  -2.555189  37.904694 -60.884747 -44.214699
# shifu               0.989233   4.543633  10.515245 -11.762891  -6.152539
# shopclues          -2.027576 -43.195995  37.418362 -41.640610 -39.338223
# shopify             1.844417 -11.237847   8.370359 -22.686089  -5.678387
# supportbee          0.949651   1.503365   2.315379  -0.056764  -2.211119
# tastykhana         -2.020121  -4.581500   7.207932  -7.472323 -17.327682
# taxiforsure        32.202000 -32.882370  57.554367 -33.614029 -40.025150
# thrill             -3.242283  -1.188352   1.027914  -2.630375  -9.485107
# tinyowl            -9.382411  -4.421027   7.034420 -34.365322 -37.362846
# tommyjams           3.247205   0.690741   0.057547  -4.402375  -2.103212
# tookitaki          -1.118954  -5.560950  -0.564683  -2.817444  -3.143879
# toppr              -3.770892  -5.937941   2.989386 -15.694386  -2.889388
# townrush            4.974627  -0.495563  -2.069747  -4.611412  -3.966743
# trideal            -0.048863  -0.693297  -3.153580  -1.081363  -0.861720
# unicommerce         0.002191  -1.908865   3.416794  -4.560795  -1.773987
# unmetric            6.081955  -4.033566   5.428592  -4.824644  -0.580772
# urban ladder        0.482300 -38.769245  22.210110 -45.997177 -58.080551
# urbanspoon         -9.384521  -6.613635  -0.484111  -7.414748  -9.321905
# vauntz             -0.435401   1.405512   2.691660  -3.027304  -1.268830
# vserv             -10.930392 -12.867811  19.468641 -34.540142 -53.926708
# webengage           6.018774  -8.205339  15.783203 -13.338528  -7.906737
# wittyfeed          -0.493594  -1.726994  -0.851867  -1.000113   0.477320
# witworks           -0.376575  -0.256876  -0.104136  -1.487626  -1.086169
# zepper              3.136124  -2.312749   4.779399  -3.245208  -1.174907
# zipdial            -6.014395 -13.084343  11.959442 -18.107550  -4.225071
#
#                      ...            190        191        192        193  \
# adiquity             ...       0.050293   0.027264  -2.518253   8.612366
# admagnet             ...      -4.567511   0.911754  -3.547191   4.137506
# antuit               ...      -0.538054   0.571629   2.161022  -0.154663
# appiterate           ...      -5.658227  -2.400817   0.530729   5.048320
# appknox              ...      -1.129043  -0.334458   2.667953   1.005267
# babyoye              ...      -1.133187   2.305391  -0.280306  12.490070
# backpacker           ...      -5.799601   4.813662   2.219124  -2.619881
# bankbazaar           ...       4.466750   3.752245  -1.856382   4.679234
# burrp                ...       8.868455   6.892417  11.599342  10.891641
# cardekho             ...       8.309375  44.495792  -4.672247  10.310476
# carwale              ...      -1.783553   3.613186  -1.304703   3.815819
# croak                ...      -1.611334   0.280765  -0.303006   1.069231
# delhivery            ...      -9.772717  12.239266  -2.129068  19.626814
# deskaway             ...      -0.824348  -0.542001   6.135825   2.527272
# doowup               ...       0.368714  -0.018953   0.550760  -0.515441
# eventifier           ...      -2.489881   1.616620   0.442690   3.266510
# exotel               ...     -12.211186  -7.582444  -2.543996   4.053044
# explara              ...      -7.361129  -8.735833  -9.221766   9.589164
# firstcry             ...      -2.916813   9.259883   3.058898  14.167669
# fitho                ...      -3.609015   6.225765   2.073525   5.209857
# fractal analytics    ...      -5.830303  22.814877  15.471120  28.212168
# freecharge           ...     -17.782902  -4.290355  14.344658  48.484055
# freshdesk            ...     -14.817947   1.664668  24.514616  27.486330
# frilp                ...       1.385574   4.874475   1.012967   1.288709
# gapoon               ...      -1.207449   2.256567   0.337578   0.545193
# hackerrank           ...      -4.433629  -2.980208   3.040060   2.959356
# heckyl               ...       3.262119   1.905591  -0.372043  -0.897560
# homebuy360           ...       3.231605  -0.749413   3.920373   0.009858
# homelane             ...       2.344000   8.572072  -0.289713   1.904903
# housing              ...       3.515211   2.847690   3.083118   7.422966
# ...                  ...            ...        ...        ...        ...
# qikpod               ...      -1.217460   1.365031   0.989385   2.638799
# quikr                ...      -3.399302  47.208084   4.681253  25.562195
# realty compass       ...      -1.613779   7.066884   6.800671   4.579819
# redbus               ...      -9.828694   8.148988   8.248392  60.766556
# rivigo               ...       2.340086   2.041459  -1.505384   3.702296
# saavn                ...     -32.140469  25.387432 -19.498238  53.652943
# shifu                ...      -6.851722   8.524524   1.823731  -0.496107
# shopclues            ...     -20.404648  24.178343  -0.204615  21.392851
# shopify              ...      -6.894443  -1.389778  -4.212901   6.479032
# supportbee           ...      -0.369646  -1.749994  -1.646091   0.348241
# tastykhana           ...      -1.375231   1.687961  -0.988624   5.910529
# taxiforsure          ...     -34.626789 -12.366998  15.206819  63.876804
# thrill               ...      -2.480770   4.508003  -2.731992  -0.095303
# tinyowl              ...     -33.054924  28.706587  -6.689119  16.228041
# tommyjams            ...      -0.654164  -2.228549   0.146206   2.783858
# tookitaki            ...       1.518380   2.304396  -2.436761   0.820452
# toppr                ...       0.180867  12.847317  -2.501047   9.516810
# townrush             ...      -1.135212   3.377920   0.794097   2.331972
# trideal              ...      -0.482109   1.750331  -1.444843   1.953984
# unicommerce          ...      -3.522217   3.379821   1.697287   7.878116
# unmetric             ...      -3.598560  -3.652515   0.693453   6.681336
# urban ladder         ...      19.548962  65.362305   8.958625  34.140778
# urbanspoon           ...      -1.083608   3.582517  -3.149023   6.962860
# vauntz               ...       0.733333   0.633649   1.297471   1.831969
# vserv                ...      -5.341581   9.185761 -37.569988  46.925858
# webengage            ...      -5.621688   0.788186   7.879859   8.621440
# wittyfeed            ...       0.133916   1.914162   0.693594  -0.264901
# witworks             ...      -0.008594   0.104600   0.425389   0.592988
# zepper               ...       2.572679   4.335157   0.113262   0.703195
# zipdial              ...     -11.696161   2.797935   6.735169   8.351502
#
#                          194        195        196        197        198  \
# adiquity          -18.424644 -13.970118  -5.562237  -0.604481  -6.980858
# admagnet           -2.416948  -2.226174  -7.540821   1.425919  -0.434645
# antuit             -0.265299  -0.951248  -2.148495  -0.355952   0.564501
# appiterate         -4.528824  -3.703933  -7.013166   1.094396  -8.381827
# appknox            -3.209018  -3.265686  -5.443894  -0.268171   2.275105
# babyoye             2.556951 -11.339587  -5.852878  -4.220149   8.814774
# backpacker         -6.649005  -6.896532  -7.878782 -11.752850 -10.834532
# bankbazaar         -0.407032  -1.340888  -8.372263  -1.045955   2.902978
# burrp             -26.310820  -7.127531 -48.843105 -14.615715 -11.575377
# cardekho          -29.380480   9.156744 -13.851773  -8.044539  -1.696608
# carwale           -10.125689  -0.930171  -6.750185  -7.277457   2.157693
# croak              -1.977802  -1.093809   1.445040  -0.998101   0.466618
# delhivery           3.857784   5.838504  -5.914740   3.557487  -7.384699
# deskaway           -5.771857  -4.585149  -4.757598  -0.645434  -1.753524
# doowup             -0.032720   0.228599  -0.709486  -1.451492  -0.016077
# eventifier         -5.576085  -9.726283  -3.055825  -5.133883  -6.491211
# exotel            -13.803105  -4.434817  -2.514012  -2.032821   2.998290
# explara            -1.837931 -10.428882 -11.872442 -29.535942  -5.563071
# firstcry           -1.832411  -6.199584  -8.232007  -3.859727  14.870881
# fitho              -1.434905   0.510389  -4.756462  -1.839010   2.865121
# fractal analytics -33.786732 -17.022636 -24.476936 -25.526905 -21.936491
# freecharge        -17.537416  -5.840470 -45.456558 -24.076464  -6.671008
# freshdesk         -61.790634  -3.873851 -41.115841 -11.955280 -18.667030
# frilp              -3.187950   1.854397  -1.981045  -2.131970  -0.739660
# gapoon             -0.966542  -1.838162   0.035350  -0.396378  -0.728683
# hackerrank         -2.316586  -1.464590  -8.124496  -9.006663  -5.580770
# heckyl             -9.795637  -4.566459  -6.040609  -5.364893  -0.910632
# homebuy360         -4.506008  -1.219621  -1.113763  -3.448462  -0.812270
# homelane            4.521947  -2.166481  -5.402291 -10.672037  -1.177650
# housing             3.961307  -7.347186  -0.046786 -15.042333  -0.692616
# ...                      ...        ...        ...        ...        ...
# qikpod              1.257742  -0.771176  -1.695591  -1.624046  -0.071864
# quikr              12.738357  24.906763 -41.919937 -63.231640  -5.449833
# realty compass     -1.812650   0.071903  -4.676585 -12.228461  -8.580713
# redbus            -63.620304 -38.953720 -61.391071 -47.331604 -11.759940
# rivigo              0.624397   0.031451  -0.618965  -1.076416  -0.845571
# saavn             -42.995651 -14.732910 -35.962276 -18.008106 -11.239285
# shifu              -3.115554  -1.156601   1.888845  -0.899857   0.323231
# shopclues           2.773521   1.956670 -40.364861 -48.924503   5.873610
# shopify            -2.213183  -5.432677 -12.794806  -2.866276   1.867995
# supportbee         -2.288322  -1.715162  -0.330772   0.690772  -0.331160
# tastykhana         -4.961618   7.228481  -8.783070  -2.281665  -4.948383
# taxiforsure       -19.278259  -3.183260 -56.566944 -99.348595 -47.714931
# thrill             -7.895522  -1.500294  -5.284987   0.703329  -3.642564
# tinyowl            -1.917855  12.765045 -29.716019 -21.081047 -14.830112
# tommyjams           1.085513  -3.371462  -2.496174  -5.780822  -2.819256
# tookitaki          -1.430837  -3.298839  -5.142608  -3.222424  -6.637712
# toppr             -10.966713   0.843984  -0.335946 -12.284795  -6.334738
# townrush            1.196842  -1.990731  -0.886914  -0.946765  -1.117804
# trideal            -0.048146  -0.144535  -0.968521  -2.899796  -0.840040
# unicommerce        -0.942453  -1.418635   1.399245  -7.757743  -5.479363
# unmetric           -2.435285   0.177966  -2.149824  -4.389665  -6.459344
# urban ladder      -24.107265   4.313647 -59.301888 -33.828686 -37.198112
# urbanspoon         -8.207751  -1.201189  -4.416105  -1.566376  -3.543848
# vauntz              0.740883   1.018638  -0.671149  -1.772523  -0.879591
# vserv             -18.790947 -47.360878 -63.108521 -27.244982 -18.871651
# webengage          -8.130288  -6.232418 -12.199720 -15.650483  -2.165277
# wittyfeed          -1.378453   1.972673  -1.119755  -0.004410   0.138005
# witworks           -1.489365   0.171654  -0.629511   0.350767  -0.553553
# zepper             -0.383208   3.181432  -2.575176  -1.902094  -6.022350
# zipdial           -16.172371 -18.380812 -19.521206 -13.868031   3.951706
#
#                          199
# adiquity           -9.185791
# admagnet           -2.847175
# antuit             -1.145812
# appiterate        -17.334711
# appknox            -5.860529
# babyoye           -10.671537
# backpacker        -11.953104
# bankbazaar        -16.861582
# burrp             -46.418579
# cardekho          -43.781349
# carwale           -13.874136
# croak               0.142807
# delhivery         -12.441776
# deskaway           -7.042910
# doowup             -1.450058
# eventifier        -12.234271
# exotel             -4.443168
# explara           -14.827088
# firstcry          -11.430929
# fitho              -4.080029
# fractal analytics -49.830437
# freecharge        -85.762299
# freshdesk         -96.592827
# frilp              -6.373382
# gapoon             -3.678247
# hackerrank        -14.056020
# heckyl             -2.910503
# homebuy360         -2.728067
# homelane           -7.218144
# housing            -9.245781
# ...                      ...
# qikpod             -1.432861
# quikr             -86.786453
# realty compass    -17.361937
# redbus            -79.552650
# rivigo             -4.746899
# saavn             -40.029846
# shifu              -9.352115
# shopclues         -28.878208
# shopify            -1.003224
# supportbee         -3.252499
# tastykhana         -4.798003
# taxiforsure       -74.501183
# thrill            -11.646112
# tinyowl           -26.363153
# tommyjams          -4.243653
# tookitaki          -4.315325
# toppr             -16.184687
# townrush           -3.899583
# trideal            -0.602343
# unicommerce        -3.589480
# unmetric           -1.307152
# urban ladder      -73.891655
# urbanspoon         -1.782425
# vauntz             -2.947447
# vserv             -33.283943
# webengage         -13.418073
# wittyfeed          -1.445448
# witworks           -1.070158
# zepper             -3.853568
# zipdial           -19.772924
#
# [96 rows x 200 columns]

# %%
all_features = pd.concat([vec_df,features],axis=1)

# %%
all_features.to_pickle('data/all_features.pkl')

# %%
all_posts.to_pickle('data/all_posts.pkl')

# %%
len(all_features)
# Out:
# 111
